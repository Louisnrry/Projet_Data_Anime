# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# !pip install matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 3.6 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.4 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.6 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [seaborn]m8/9 [seaborn]ib]
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('animes.csv')
df.head()
# Out:
#                               Anime           Genre_Tags    Source  \
# 0                            Naruto      Action / Shonen     Manga
# 1                            Trigun      Sci-Fi / Action     Manga
# 2                     Dragon Ball Z      Action / Shonen     Manga
# 3  Fullmetal Alchemist: Brotherhood  Aventure / Military     Manga
# 4                      Cowboy Bebop        Sci-Fi / Noir  Original
#
#    Nb_Episodes Status          Studio    Date_Pub  Note_Globale  \
# 0          220   Fini  Studio Pierrot  2002-10-03           8.4
# 1           26   Fini        Madhouse  1998-04-01           8.2
# 2          291   Fini  Toei Animation  1989-04-26           8.7
# 3           64   Fini           Bones  2009-04-05           9.1
# 4           26   Fini         Sunrise  1998-04-03           8.8
#
#    Note_Meilleur_Ep                   Meilleur_Ep_Titre  \
# 0               9.6           Ep 133: Le cri des larmes
# 1               9.1               Ep 24: Le péché (Sin)
# ...

# %%
df = df[ ~((df['Status'] == 'En cours') & (df['Nb_Episodes'] < 30)) ]

# %%
df.head()
# Out:
#                               Anime           Genre_Tags    Source  \
# 0                            Naruto      Action / Shonen     Manga
# 1                            Trigun      Sci-Fi / Action     Manga
# 2                     Dragon Ball Z      Action / Shonen     Manga
# 3  Fullmetal Alchemist: Brotherhood  Aventure / Military     Manga
# 4                      Cowboy Bebop        Sci-Fi / Noir  Original
#
#    Nb_Episodes Status          Studio    Date_Pub  Note_Globale  \
# 0          220   Fini  Studio Pierrot  2002-10-03           8.4
# 1           26   Fini        Madhouse  1998-04-01           8.2
# 2          291   Fini  Toei Animation  1989-04-26           8.7
# 3           64   Fini           Bones  2009-04-05           9.1
# 4           26   Fini         Sunrise  1998-04-03           8.8
#
#    Note_Meilleur_Ep                   Meilleur_Ep_Titre  \
# 0               9.6           Ep 133: Le cri des larmes
# 1               9.1               Ep 24: Le péché (Sin)
# ...

# %%
pd.set_option('display.max_columns', None)

# Affiche TOUT le texte dans les cases (pour lire les commentaires en entier)
pd.set_option('display.max_colwidth', None)

# Affiche TOUTES les lignes (Attention : à utiliser avec prudence si vous avez +1000 lignes)
pd.set_option('display.max_rows', None)

# Maintenant, regardez votre tableau
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 15          Du mouvement de la Terre            Historical / Drama
# 16                  Samurai Champloo          Adventure / Chanbara
# ...

# %%
print (df)
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 15          Du mouvement de la Terre            Historical / Drama
# 16                  Samurai Champloo          Adventure / Chanbara
# ...

# %%
pd.set_option('display.max_columns', None)

# Affiche TOUT le texte dans les cases (pour lire les commentaires en entier)
pd.set_option('display.max_colwidth', None)

# Affiche TOUTES les lignes (Attention : à utiliser avec prudence si vous avez +1000 lignes)
pd.set_option('display.max_rows', None)

# Maintenant, regardez votre tableau
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.set_option('display.max_columns', None)
#       3 # Affiche TOUT le texte dans les cases (pour lire les commentaires en entier)
#       4 pd.set_option('display.max_colwidth', None)
#
# NameError: name 'pd' is not defined

# %%
print (df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print (df)
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('animes.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('animes.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('animes.csv')

# %%
df
# Out:
#                                Anime              Genre_Tags    Source  \
# 0                             Naruto         Action / Shonen     Manga
# 1                             Trigun         Sci-Fi / Action     Manga
# 2                      Dragon Ball Z         Action / Shonen     Manga
# 3   Fullmetal Alchemist: Brotherhood     Aventure / Military     Manga
# 4                       Cowboy Bebop           Sci-Fi / Noir  Original
# ..                               ...                     ...       ...
# 56                        SPY×FAMILY  Comedy / Slice of Life     Manga
# 57                        Dan Da Dan   Action / Supernatural     Manga
# 58                     Made in Abyss     Adventure / Mystery     Manga
# 59                   Kuroko's Basket      Sport / Basketball     Manga
# 60                    Mob Psycho 100   Action / Supernatural     Manga
#
#     Nb_Episodes    Status             Studio    Date_Pub  Note_Globale  \
# ...

# %%
pd.set_option('display.max_columns', None)

# Affiche TOUT le texte dans les cases (pour lire les commentaires en entier)
pd.set_option('display.max_colwidth', None)

# Affiche TOUTES les lignes (Attention : à utiliser avec prudence si vous avez +1000 lignes)
pd.set_option('display.max_rows', None)

# Maintenant, regardez votre tableau
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
clear

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('animes.csv')

# %%
df
# Out:
#                                Anime              Genre_Tags    Source  \
# 0                             Naruto         Action / Shonen     Manga
# 1                             Trigun         Sci-Fi / Action     Manga
# 2                      Dragon Ball Z         Action / Shonen     Manga
# 3   Fullmetal Alchemist: Brotherhood     Aventure / Military     Manga
# 4                       Cowboy Bebop           Sci-Fi / Noir  Original
# ..                               ...                     ...       ...
# 56                        SPY×FAMILY  Comedy / Slice of Life     Manga
# 57                        Dan Da Dan   Action / Supernatural     Manga
# 58                     Made in Abyss     Adventure / Mystery     Manga
# 59                   Kuroko's Basket      Sport / Basketball     Manga
# 60                    Mob Psycho 100   Action / Supernatural     Manga
#
#     Nb_Episodes    Status             Studio    Date_Pub  Note_Globale  \
# ...

# %%
pd.set_option('display.max_columns', None)

# Affiche TOUT le texte dans les cases (pour lire les commentaires en entier)
pd.set_option('display.max_colwidth', None)

# Affiche TOUTES les lignes (Attention : à utiliser avec prudence si vous avez +1000 lignes)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df=df [~("Status")==("En Cours")&("Nb_Episodes"<30)]
# Out:
#   Cell In[6], line 1
#     df=df [~("Status")==("En Cours")&("Nb_Episodes"<30)
#                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
df=df [~("Status")==("En Cours")&("Nb_Episodes"<30)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=df [~("Status")==("En Cours")&("Nb_Episodes"<30)]
#
# TypeError: bad operand type for unary ~: 'str'

# %%
df=df [~('Status')==('En Cours')&('Nb_Episodes'<30)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df=df [~('Status')==('En Cours')&('Nb_Episodes'<30)]
#
# TypeError: bad operand type for unary ~: 'str'

# %%
df=df [~df(('Status'=='En Cours')&df('Nb_Episodes'<30))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df=df [~df(('Status'=='En Cours')&df('Nb_Episodes'<30))]
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
df=df [~((df['Status']==['En Cours'])&df(['Nb_Episodes'<30]))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df=df [~((df['Status']==['En Cours'])&df(['Nb_Episodes'<30]))]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
# ...

# %%
df=df [~((df['Status']==['En Cours'])&df['Nb_Episodes'<30))]
# Out:
#   Cell In[11], line 1
#     df=df [~((df['Status']==['En Cours'])&df['Nb_Episodes'<30))]
#                                                              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df=df [~((df['Status']==['En Cours'])&df['Nb_Episodes'<30)
# Out:
#   Cell In[12], line 1
#     df=df [~((df['Status']==['En Cours'])&df['Nb_Episodes'<30)
#                                                              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df=df [~((df['Status']==['En Cours'])&df['Nb_Episodes'<30])
# Out:
#   Cell In[13], line 1
#     df=df [~((df['Status']==['En Cours'])&df['Nb_Episodes'<30])
#                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
df=df [~((df['Status']=='En Cours')&df['Nb_Episodes']<30)
# Out:
#   Cell In[14], line 1
#     df=df [~((df['Status']=='En Cours')&df['Nb_Episodes']<30)
#                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
df=df [~((df['Status'])=='En Cours'&df['Nb_Episodes']<30)
# Out:
#   Cell In[15], line 1
#     df=df [~((df['Status'])=='En Cours'&df['Nb_Episodes']<30)
#                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
df=df [~((df['Status']=='En Cours')&df['Nb_Episodes']<30)
# Out:
#   Cell In[16], line 1
#     df=df [~((df['Status']=='En Cours')&df['Nb_Episodes']<30)
#                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
df=df [~((df['Status']=='En Cours')&(df['Nb_Episodes']<30))]

# %%
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df=df [~((df['Nb_Episodes']<10))]

# %%
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df=df [~((df['Status']=='En Cours')&(df['Nb_Episodes']<30))]
df=df [~((df['Nb_Episodes']<10))]
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Anime              59 non-null     object
#  1   Genre_Tags         59 non-null     object
#  2   Source             59 non-null     object
#  3   Nb_Episodes        59 non-null     int64
#  4   Status             59 non-null     object
#  5   Studio             59 non-null     object
#  6   Date_Pub           59 non-null     object
#  7   Note_Globale       59 non-null     float64
#  8   Note_Meilleur_Ep   59 non-null     float64
#  9   Meilleur_Ep_Titre  59 non-null     object
#  10  Comm_Meilleur_Ep   59 non-null     object
#  11  Note_Pire_Ep       59 non-null     float64
#  12  Pire_Ep_Titre      59 non-null     object
#  13  Comm_Pire_Ep       59 non-null     object
#  14  Comm_Saison_1      59 non-null     object
#  15  Comm_Saison_2      59 non-null     object
# ...

# %%
print(df['Status'].unique())
# Out:
# ['Fini' 'En cours' 'En pause']

# %%
df=df [~((df['Status']=='En Cours')&(df['Nb_Episodes']<30))]
df=df [~((df['Nb_Episodes']<10))]
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df = df[~((df['Status']=='En Cours') & (df['Nb_Episodes']<30))]
df = df[df['Nb_Episodes'] >= 10]
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df = df[~((df['Status'] == 'En Cours') & (df['Nb_Episodes'] < 30))]
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df.to_csv('/mnt/user-data/uploads/animes.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.to_csv('/mnt/user-data/uploads/animes.csv', index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df.to_csv('animes.csv', index=False)

# %%
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df = df[~((df['Status']=='En Cours') & (df['Nb_Episodes']<30))]
df = df[df['Nb_Episodes'] >= 10]
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df = df[~((df['Status']=='En Cours') & (df['Nb_Episodes']<30))]
df = df[df['Nb_Episodes'] >= 10]
df.to_csv('animes.csv', index=False)
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df.head()
# Out:
#                               Anime           Genre_Tags    Source  \
# 0                            Naruto      Action / Shonen     Manga
# 1                            Trigun      Sci-Fi / Action     Manga
# 2                     Dragon Ball Z      Action / Shonen     Manga
# 3  Fullmetal Alchemist: Brotherhood  Aventure / Military     Manga
# 4                      Cowboy Bebop        Sci-Fi / Noir  Original
#
#    Nb_Episodes Status          Studio    Date_Pub  Note_Globale  \
# 0          220   Fini  Studio Pierrot  2002-10-03           8.4
# 1           26   Fini        Madhouse  1998-04-01           8.2
# 2          291   Fini  Toei Animation  1989-04-26           8.7
# 3           64   Fini           Bones  2009-04-05           9.1
# 4           26   Fini         Sunrise  1998-04-03           8.8
#
#    Note_Meilleur_Ep                   Meilleur_Ep_Titre  \
# 0               9.6           Ep 133: Le cri des larmes
# 1               9.1               Ep 24: Le péché (Sin)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Anime              59 non-null     object
#  1   Genre_Tags         59 non-null     object
#  2   Source             59 non-null     object
#  3   Nb_Episodes        59 non-null     int64
#  4   Status             59 non-null     object
#  5   Studio             59 non-null     object
#  6   Date_Pub           59 non-null     object
#  7   Note_Globale       59 non-null     float64
#  8   Note_Meilleur_Ep   59 non-null     float64
#  9   Meilleur_Ep_Titre  59 non-null     object
#  10  Comm_Meilleur_Ep   59 non-null     object
#  11  Note_Pire_Ep       59 non-null     float64
#  12  Pire_Ep_Titre      59 non-null     object
#  13  Comm_Pire_Ep       59 non-null     object
#  14  Comm_Saison_1      59 non-null     object
#  15  Comm_Saison_2      59 non-null     object
# ...

# %%
df.isna().sum()
# Out:
# Anime                 0
# Genre_Tags            0
# Source                0
# Nb_Episodes           0
# Status                0
# Studio                0
# Date_Pub              0
# Note_Globale          0
# Note_Meilleur_Ep      0
# Meilleur_Ep_Titre     0
# Comm_Meilleur_Ep      0
# Note_Pire_Ep          0
# Pire_Ep_Titre         0
# Comm_Pire_Ep          0
# Comm_Saison_1         0
# Comm_Saison_2         0
# Comm_Saison_3        10
# dtype: int64

# %%
# Out:
# np.float64(0.5882352941176471)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('animes.csv')

# %%
df = df[~((df['Status']=='En Cours') & (df['Nb_Episodes']<30))]
df = df[df['Nb_Episodes'] >= 10]
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df = df[~((df['Status']=='En Cours') & (df['Nb_Episodes']<30))]

# %%
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/48/6s2kc7ms0rv3xdprkwpp0n080000gn/T/ipykernel_15633/2465499897.py in ?()
# ----> 1 df.type()
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Anime              59 non-null     object
#  1   Genre_Tags         59 non-null     object
#  2   Source             59 non-null     object
#  3   Nb_Episodes        59 non-null     int64
#  4   Status             59 non-null     object
#  5   Studio             59 non-null     object
#  6   Date_Pub           59 non-null     object
#  7   Note_Globale       59 non-null     float64
#  8   Note_Meilleur_Ep   59 non-null     float64
#  9   Meilleur_Ep_Titre  59 non-null     object
#  10  Comm_Meilleur_Ep   59 non-null     object
#  11  Note_Pire_Ep       59 non-null     float64
#  12  Pire_Ep_Titre      59 non-null     object
#  13  Comm_Pire_Ep       59 non-null     object
#  14  Comm_Saison_1      59 non-null     object
#  15  Comm_Saison_2      59 non-null     object
# ...

# %%
df.dtypes
# Out:
# Anime                 object
# Genre_Tags            object
# Source                object
# Nb_Episodes            int64
# Status                object
# Studio                object
# Date_Pub              object
# Note_Globale         float64
# Note_Meilleur_Ep     float64
# Meilleur_Ep_Titre     object
# Comm_Meilleur_Ep      object
# Note_Pire_Ep         float64
# Pire_Ep_Titre         object
# Comm_Pire_Ep          object
# Comm_Saison_1         object
# Comm_Saison_2         object
# Comm_Saison_3         object
# dtype: object

# %%
df.columns
# Out:
# Index(['Anime', 'Genre_Tags', 'Source', 'Nb_Episodes', 'Status', 'Studio',
#        'Date_Pub', 'Note_Globale', 'Note_Meilleur_Ep', 'Meilleur_Ep_Titre',
#        'Comm_Meilleur_Ep', 'Note_Pire_Ep', 'Pire_Ep_Titre', 'Comm_Pire_Ep',
#        'Comm_Saison_1', 'Comm_Saison_2', 'Comm_Saison_3'],
#       dtype='object')

# %%
df.shape
# Out:
# (59, 17)

# %%
df.describe()
# Out:
#        Nb_Episodes  Note_Globale  Note_Meilleur_Ep  Note_Pire_Ep
# count    59.000000     59.000000         59.000000     59.000000
# mean     93.627119      8.320339          9.344068      6.815254
# std     164.037306      0.528752          0.450774      1.064281
# min      12.000000      6.000000          8.300000      2.700000
# 25%      25.000000      8.150000          9.100000      6.250000
# 50%      37.000000      8.400000          9.500000      7.200000
# 75%      80.500000      8.650000          9.700000      7.500000
# max    1090.000000      9.300000          9.900000      8.400000

# %%
df.srt.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/48/6s2kc7ms0rv3xdprkwpp0n080000gn/T/ipykernel_15633/1481825362.py in ?()
# ----> 1 df.srt.lower()
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'srt'

# %%
df.infos()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/48/6s2kc7ms0rv3xdprkwpp0n080000gn/T/ipykernel_15633/3450010504.py in ?()
# ----> 1 df.infos()
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'infos'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Anime              59 non-null     object
#  1   Genre_Tags         59 non-null     object
#  2   Source             59 non-null     object
#  3   Nb_Episodes        59 non-null     int64
#  4   Status             59 non-null     object
#  5   Studio             59 non-null     object
#  6   Date_Pub           59 non-null     object
#  7   Note_Globale       59 non-null     float64
#  8   Note_Meilleur_Ep   59 non-null     float64
#  9   Meilleur_Ep_Titre  59 non-null     object
#  10  Comm_Meilleur_Ep   59 non-null     object
#  11  Note_Pire_Ep       59 non-null     float64
#  12  Pire_Ep_Titre      59 non-null     object
#  13  Comm_Pire_Ep       59 non-null     object
#  14  Comm_Saison_1      59 non-null     object
#  15  Comm_Saison_2      59 non-null     object
# ...

# %%
df['Date_Pub'] = pd.to_datetime(df['Date_Pub'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Anime              59 non-null     object
#  1   Genre_Tags         59 non-null     object
#  2   Source             59 non-null     object
#  3   Nb_Episodes        59 non-null     int64
#  4   Status             59 non-null     object
#  5   Studio             59 non-null     object
#  6   Date_Pub           59 non-null     datetime64[ns]
#  7   Note_Globale       59 non-null     float64
#  8   Note_Meilleur_Ep   59 non-null     float64
#  9   Meilleur_Ep_Titre  59 non-null     object
#  10  Comm_Meilleur_Ep   59 non-null     object
#  11  Note_Pire_Ep       59 non-null     float64
#  12  Pire_Ep_Titre      59 non-null     object
#  13  Comm_Pire_Ep       59 non-null     object
#  14  Comm_Saison_1      59 non-null     object
#  15  Comm_Saison_2      59 non-null     object
# ...

# %%
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df = df[~((df['Status']=='En Cours') & (df['Nb_Episodes']<30))]
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %%
df['Nb_Episodes']
# Out:
# 0      220
# 1       26
# 2      291
# 3       64
# 4       26
# 5       25
# 6       50
# 7       57
# 8     1090
# 9       36
# 10      85
# 11      24
# 12      12
# 13      24
# 14      26
# 15      89
# 16      37
# 17     148
# 18      50
# 19      24
# 20      43
# 21     500
# 22      41
# 23     138
# 24     366
# 25      24
# 26      55
# 27      12
# 28      48
# 29      26
# 30      26
# 31      47
# 32     293
# 33      28
# 34      13
# 35      13
# 36      26
# 37      26
# 38      89
# 39      25
# 40      24
# 41      22
# 42      74
# 43      76
# 44      95
# 45     112
# 46      55
# 47      32
# 48     170
# 49      23
# 50      12
# 51      48
# 52     328
# 53      24
# 54      37
# 55      12
# 56      25
# 57      75
# 58      37
# Name: Nb_Episodes, dtype: int64

# %%
df['Status

# %%
df['Status'

# %%
df['Status']
# Out:
# 0         Fini
# 1         Fini
# 2         Fini
# 3         Fini
# 4         Fini
# 5         Fini
# 6         Fini
# 7     En cours
# 8     En cours
# 9     En cours
# 10        Fini
# 11    En cours
# 12    En cours
# 13    En cours
# 14        Fini
# 15        Fini
# 16        Fini
# 17        Fini
# 18        Fini
# 19        Fini
# 20        Fini
# 21        Fini
# 22        Fini
# 23    En cours
# 24        Fini
# 25        Fini
# 26    En cours
# 27        Fini
# 28        Fini
# 29        Fini
# 30        Fini
# 31    En cours
# 32    En pause
# 33    En cours
# 34    En cours
# 35    En cours
# 36        Fini
# 37        Fini
# 38        Fini
# 39        Fini
# 40        Fini
# 41        Fini
# 42        Fini
# 43        Fini
# 44        Fini
# 45        Fini
# 46    En cours
# 47    En cours
# 48    En pause
# 49        Fini
# 50    En cours
# 51    En cours
# 52    En cours
# 53    En cours
# 54    En cours
# 55    En cours
# 56    En cours
# 57        Fini
# ...

# %%
df[['status']&['Nb_Episodes]<30]
# Out:
#   Cell In[60], line 1
#     df[['status']&['Nb_Episodes]<30]
#                                     ^
# SyntaxError: EOL while scanning string literal

# %%
df[(df['Status'] == 'En Cours') & (df['Nb_Episodes'] < 30)]
# Out:
# Empty DataFrame
# Columns: [Anime, Genre_Tags, Source, Nb_Episodes, Status, Studio, Date_Pub, Note_Globale, Note_Meilleur_Ep, Meilleur_Ep_Titre, Comm_Meilleur_Ep, Note_Pire_Ep, Pire_Ep_Titre, Comm_Pire_Ep, Comm_Saison_1, Comm_Saison_2, Comm_Saison_3]
# Index: []

# %%
sns.set_theme(style="whitegrid")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.set_theme(style="whitegrid")
#
# NameError: name 'sns' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('animes.csv')

# %%
sns.set_theme(style="whitegrid")

# %%
plt.figure(figsize=(10, 6))
top_10 = df.sort_values(by='Note_Globale', ascending=False).head(10)
sns.barplot(x='Note_Globale', y='Anime', data=top_10, palette='viridis')
# Out:
# /var/folders/48/6s2kc7ms0rv3xdprkwpp0n080000gn/T/ipykernel_10596/3299264199.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Note_Globale', y='Anime', data=top_10, palette='viridis')
# <Axes: xlabel='Note_Globale', ylabel='Anime'>

# %%
plt.figure(figsize=(10, 6))
top_10 = df.sort_values(by='Note_Globale', ascending=False).head(10)
sns.barplot(x='Note_Globale', y='Anime', data=top_10, palette='viridis')

plt.title('Top 10 des Animes les mieux notés', fontsize=15)
plt.xlabel('Note Globale')
plt.ylabel('Anime')
plt.xlim(8, 10)  # On zoome entre 8 et 10 pour mieux voir les écarts
plt.show()
# Out:
# /var/folders/48/6s2kc7ms0rv3xdprkwpp0n080000gn/T/ipykernel_10596/3302202002.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Note_Globale', y='Anime', data=top_10, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
top_10 = df.sort_values(by='Note_Globale', ascending=False).head(10)

# CORRECTION ICI : Ajout de hue et legend=False pour éviter l'erreur rouge
sns.barplot(x='Note_Globale', y='Anime', data=top_10, palette='viridis', hue='Anime', legend=False)

plt.title('Top 10 des Animes les mieux notés', fontsize=15)
plt.xlabel('Note Globale')
plt.ylabel('Anime')
plt.xlim(8, 10)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Nb_Episodes', y='Note_Globale', data=df, hue='Source', s=100, alpha=0.8)

plt.title('Est-ce que les animes longs sont meilleurs ?', fontsize=15)
plt.xlabel('Nombre d\'épisodes (échelle log)')
plt.ylabel('Note Globale')
plt.xscale('log')
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
avg_source = df.groupby('Source')['Note_Globale'].mean().sort_values(ascending=False).reset_index()

sns.barplot(x='Note_Globale', y='Source', data=avg_source, palette='magma', hue='Source', legend=False)

plt.title('Note moyenne selon l\'origine de l\'œuvre', fontsize=15)
plt.xlabel('Note Moyenne')
plt.xlim(7, 9.5)
plt.show()

# %%
df['Ecart'] = df['Note_Meilleur_Ep'] - df['Note_Pire_Ep']

# %%
df['Regularite'] = 10 - df['Ecart']

# %%
import numpy as np

# %%
df['Longueur'] = np.log(df['Nb_Episodes'])

# %%
print(df[['Anime', 'Regularite', 'Longueur', 'Ecart']].head())
# Out:
#                               Anime  Regularite  Longueur  Ecart
# 0                            Naruto         6.2  5.393628    3.8
# 1                            Trigun         7.4  3.258097    2.6
# 2                     Dragon Ball Z         6.5  5.673323    3.5
# 3  Fullmetal Alchemist: Brotherhood         6.7  4.158883    3.3
# 4                      Cowboy Bebop         7.5  3.258097    2.5

# %%
df['Ecart'] = df['Note_Meilleur_Ep'] - df['Note_Pire_Ep']
df['Regularite'] = 10 - df['Ecart']
df['Longueur'] = np.log(df['Nb_Episodes'])
print(df[['Anime', 'Regularite', 'Longueur', 'Ecart']].head())
# Out:
#                               Anime  Regularite  Longueur  Ecart
# 0                            Naruto         6.2  5.393628    3.8
# 1                            Trigun         7.4  3.258097    2.6
# 2                     Dragon Ball Z         6.5  5.673323    3.5
# 3  Fullmetal Alchemist: Brotherhood         6.7  4.158883    3.3
# 4                      Cowboy Bebop         7.5  3.258097    2.5

# %%
df['Ecart'] = df['Note_Meilleur_Ep'] - df['Note_Pire_Ep']
df['Regularite'] = 10 - df['Ecart']
df['Longueur'] = np.log(df['Nb_Episodes'])
print(df[['Anime', 'Regularite','Note 'Ecart']].head())
# Out:
#                               Anime  Regularite  Ecart
# 0                            Naruto         6.2    3.8
# 1                            Trigun         7.4    2.6
# 2                     Dragon Ball Z         6.5    3.5
# 3  Fullmetal Alchemist: Brotherhood         6.7    3.3
# 4                      Cowboy Bebop         7.5    2.5
